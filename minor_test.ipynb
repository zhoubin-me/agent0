# %%
import gym
import os
import random
import time
import cv2
import copy
import numpy as np
import collections
import matplotlib.pyplot as plt
import json
import scipy
import argparse
from PIL import Image
from collections import deque
from tqdm import tqdm
import ray
from scipy.signal import savgol_filter
# plt.style.use('')


import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.multiprocessing as mp
import torchvision as tv
from torch.utils.data import Dataset
import pickle

from src.common.atari_wrappers import wrap_deepmind, make_atari
from src.common.utils import LinearSchedule, DataLoaderX, DataPrefetcher, ReplayDataset
from src.common.vec_env import ShmemVecEnv, VecEnvWrapper, DummyVecEnv
from src.agents.model import NatureCNN

# %%
num_env = 16
num_actors = 8
total_steps = int(1e7)
epoches = 1000
update_per_data = 8
replay_size = int(1e6)
discount = 0.99
batch_size = 512
lr = 1e-3

target_net_update_freq = 250
exploration_ratio = 0.2
steps_per_epoch = total_steps // epoches

# %%
def make_env(game, episode_life=True, clip_rewards=True):
    env = make_atari(f'{game}NoFrameskip-v4')
    env = wrap_deepmind(env, episode_life=episode_life, clip_rewards=clip_rewards, frame_stack=True, scale=False, transpose_image=True)
    return env

def parse_arguments():
    parser = argparse.ArgumentParser()

    parser.add_argument("--game", type=str, default="Breakout")
    parser.add_argument("--replay_size", type=int, default=int(1e6))
    parser.add_argument("--batch_size", type=int, default=1024)
    parser.add_argument("--lr", type=float, default=1e-4)
    parser.add_argument("--gpu_id", type=int, default=9)
    parser.add_argument("--discount", type=float, default=0.99)
    parser.add_argument("--exploration_steps", type=int, default=20000)
    parser.add_argument("--max_step", type=int, default=int(1e7))
    parser.add_argument("--seed", type=int, default=1234)
    parser.add_argument("--num_env", type=int, default=16)

    args = parser.parse_args()
    print("input args:\n", json.dumps(vars(args), indent=4, separators=(",", ":")))
    return args

# %%
@ray.remote(num_gpus=0.125)
class Actor:
    def __init__(self, rank, game):
        if rank < num_actors:
            self.envs = ShmemVecEnv([lambda: make_env(game) for _ in range(num_env)], context='fork')
        else:
            self.envs = ShmemVecEnv([lambda: make_env(game, False, False) for _ in range(num_env)], context='fork')
        self.R = np.zeros(num_env)
        self.obs = self.envs.reset()
        self.state_shape, self.action_dim = self.envs.observation_space.shape, self.envs.action_space.n
        self.model = NatureCNN(self.state_shape[0], self.action_dim).cuda()
        self.rank = rank
    
    def sample(self, epsilon, state_dict):
        self.model.load_state_dict(state_dict)
        steps = steps_per_epoch // (num_env * num_actors)
        Rs, Qs = [], []
        tic = time.time()
        local_replay = deque(maxlen=replay_size)
        for step in range(steps):
            action_random = np.random.randint(0, self.action_dim, num_env)
            st = torch.from_numpy(np.array(self.obs)).float().cuda() / 255.0
            qs = self.model(st)
            qs_max, qs_argmax = qs.max(dim=-1)
            action_greedy = qs_argmax.tolist()
            Qs.append(qs_max.mean().item())
            action = [act_grd if p > epsilon else act_rnd for p, act_rnd, act_grd in zip(np.random.rand(num_env), action_random, action_greedy)]
    
            obs_next, reward, done, info = self.envs.step(action)
            for entry in zip(self.obs, action, reward, obs_next, done):
                local_replay.append(entry)
            self.obs = obs_next
            self.R += np.array(reward)
            for idx, d in enumerate(done):
                if d:
                    Rs.append(self.R[idx])
                    self.R[idx] = 0
        toc = time.time()
        # print(f"Rank {self.rank}, Data Collection Time: {toc - tic}, Speed {steps_per_epoch / (toc - tic)}")
        return local_replay, Rs, Qs, self.rank

# %%
class Agent:
    def __init__(self, game):
        test_env = make_env(game)
        self.state_shape, self.action_dim = test_env.observation_space.shape, test_env.action_space.n
        self.model = NatureCNN(self.state_shape[0], self.action_dim).cuda()
        self.model_target = copy.deepcopy(self.model).cuda()
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr)
        self.replay = deque(maxlen=replay_size)
        self.update_steps = 0
        self.device = torch.device('cuda:0')
        
    def get_datafetcher(self):
        dataset = ReplayDataset(self.replay)
        dataloader = DataLoaderX(dataset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)
        datafetcher = DataPrefetcher(dataloader, self.device)
        return datafetcher
    
    def append_data(self, data):
        self.replay.extend(data)
    
    def train_step(self):
        try:
            data = self.prefetcher.next()
        except:
            self.prefetcher = self.get_datafetcher()
            data = self.prefetcher.next()

        states, actions, rewards, next_states, terminals = data
        states = states.float() / 255.0
        next_states = next_states.float() / 255.0
        actions = actions.long()
        terminals = terminals.float()
        rewards = rewards.float()

        with torch.no_grad():
            q_next = self.model_target(next_states)
            q_next_online = self.model(next_states)
            q_next = q_next.gather(1, q_next_online.argmax(dim=-1).unsqueeze(-1)).squeeze(-1)
            q_target = rewards + discount * (1 - terminals) * q_next

        q = self.model(states).gather(1, actions.unsqueeze(-1)).squeeze(-1)
        loss = F.smooth_l1_loss(q, q_target)
        
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        self.update_steps += 1

        if self.update_steps % 250 == 0:
            self.model_target.load_state_dict(self.model.state_dict())
        return loss.detach()

# %%
def formated_print(var_name, xs):
    if len(xs) > 0:
        print("{0} mean/std/max/min\t {1:12.6f}\t{2:12.6f}\t{3:12.6f}\t{4:12.6}".format(
            var_name, np.mean(xs), np.std(xs), np.max(xs), np.min(xs)))

def train(game):
    ray.init()
    epsilon_schedule = LinearSchedule(1.0, 0.01, int(total_steps * exploration_ratio))
    actors = [Actor.remote(rank, game) for rank in range(num_actors + 1)]
    tester = actors[-1]
    
    agent = Agent(game)
    sample_ops = [a.sample.remote(1.0, agent.model.state_dict()) for a in actors]
    
    TRRs, RRs, QQs, LLs = [], [], [], []
    for local_replay, Rs, Qs, rank in ray.get(sample_ops): # + [test_op]):
        if rank < num_actors:
            agent.append_data(local_replay)
            RRs += Rs
            QQs += Qs
        else:
            TRRs += Rs
            
    
    formated_print("Warming up Reward", RRs)
    formated_print("Warming up Qmax", QQs)
        
    steps = 0
    epoch = 0
    tic = time.time()
    while True:
        done_id, sample_ops = ray.wait(sample_ops)
        data = ray.get(done_id)
        local_replay, Rs, Qs, rank = data[0]
        
        if rank < num_actors:
            # Actor
            agent.append_data(local_replay)
            steps += len(local_replay)
            epsilon = epsilon_schedule(len(local_replay))
            if epsilon == 0.01:
                epsilon=np.random.choice([0.01, 0.02, 0.05, 0.1], p=[0.7, 0.1, 0.1, 0.1])
            
            sample_ops.append(actors[rank].sample.remote(epsilon, agent.model.state_dict()))
            RRs += Rs
            QQs += Qs
        else:
            # Tester
            sample_ops.append(tester.sample.remote(0.01, agent.model.state_dict()))
            TRRs += Rs
        
        # Trainer
        for _ in range(16):
            loss = agent.train_step()
            LLs.append(loss)
        
        if (steps // steps_per_epoch) > epoch:
            if epoch % 10 == 0:
                toc = time.time()
                print("=" * 100)
                print(f"Epoch: {epoch:5d}\t Steps: {steps:10d}\t Average Speed: {steps / (toc - tic):8.2f}\t Epsilon: {epsilon}")
                print('-' * 100)
                formated_print("EP Training Reward", RRs[-1000:])
                formated_print("EP Loss           ", torch.stack(LLs).tolist()[-1000:])
                formated_print("EP Qmax           ", QQs[-1000:])
                if len(TRRs) > 0:
                    formated_print("EP Test Reward    ", TRRs[-1000:])
                    
                print("=" * 100)
                print(" " * 100)
            
            if epoch % 50 == 0:
                torch.save({
                    'model': agent.model.state_dict(),
                    'optim': agent.optimizer.state_dict(),
                    'epoch': epoch,
                    'epsilon': epsilon,
                    'steps': steps,
                    'Rs': RRs,
                    'TRs': TRRs,
                    'Qs': QQs,
                    'Ls': LLs,
                    'time': toc - tic,
                }, f'ckpt/{game}_e{epoch:04d}.pth')
            
            epoch += 1
            if epoch == 10:
                sample_ops.append(tester.sample.remote(0.01, agent.model.state_dict()))
            if epoch > epoches:
                ray.shutdown()
                return

# %%
if __name__ == '__main__':
    # args = parse_arguments()
    # game = args.game
    game = "Enduro"
    train(game)
# Out:
# 2020-08-03 15:56:30,749	INFO resource_spec.py:212 -- Starting Ray with 199.51 GiB memory available for workers and up to 89.51 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-08-03 15:56:31,181	WARNING services.py:923 -- Redis failed to start, retrying now.
# 2020-08-03 15:56:31,973	WARNING services.py:923 -- Redis failed to start, retrying now.
# 2020-08-03 15:56:33,261	INFO services.py:1165 -- View the Ray dashboard at localhost:8266
# /home/bzhou/miniconda3/lib/python3.6/site-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)
# (pid=25426) Logging to /tmp/openai-2020-08-03-15-56-35-863848
# (pid=25426) Creating dummy env object to get spaces
# (pid=25420) Logging to /tmp/openai-2020-08-03-15-56-35-894437
# (pid=25420) Creating dummy env object to get spaces
# (pid=25405) Logging to /tmp/openai-2020-08-03-15-56-35-881545
# (pid=25405) Creating dummy env object to get spaces
# (pid=25432) Logging to /tmp/openai-2020-08-03-15-56-35-896994
# (pid=25432) Creating dummy env object to get spaces
# (pid=25422) Logging to /tmp/openai-2020-08-03-15-56-35-900666
# (pid=25422) Creating dummy env object to get spaces
# (pid=25425) Logging to /tmp/openai-2020-08-03-15-56-35-935145
# (pid=25425) Creating dummy env object to get spaces
# (pid=25456) Logging to /tmp/openai-2020-08-03-15-56-35-908752
# (pid=25456) Creating dummy env object to get spaces
# (pid=25424) Logging to /tmp/openai-2020-08-03-15-56-35-973978
# (pid=25424) Creating dummy env object to get spaces
# (pid=25415) Logging to /tmp/openai-2020-08-03-15-56-35-977450
# (pid=25415) Creating dummy env object to get spaces
# Warming up Qmax mean/std/max/min	     0.144084	    0.009416	    0.170281	    0.115748
# ====================================================================================================
# Epoch:     0	 Steps:      11232	 Average Speed:   837.94	 Epsilon: 0.9950579199999998
# ----------------------------------------------------------------------------------------------------
# EP Loss            mean/std/max/min	     0.019994	    0.215508	    2.855203	 0.000210002
# EP Qmax            mean/std/max/min	     0.144854	    0.008926	    0.175072	    0.115748
# ====================================================================================================
#
# ====================================================================================================
# Epoch:    10	 Steps:     111072	 Average Speed:  1454.09	 Epsilon: 0.945637119999998
# ----------------------------------------------------------------------------------------------------
# EP Loss            mean/std/max/min	     0.000038	    0.000042	    0.000380	 1.44334e-05
# EP Qmax            mean/std/max/min	     0.323674	    0.127940	    0.447709	    0.125258
# ====================================================================================================
#
# ====================================================================================================
# Epoch:    20	 Steps:     210912	 Average Speed:  1562.98	 Epsilon: 0.8962163199999962
# ----------------------------------------------------------------------------------------------------
# EP Loss            mean/std/max/min	     0.000045	    0.000039	    0.000255	 8.41747e-06
# EP Qmax            mean/std/max/min	     0.143392	    0.042976	    0.383992	   0.0996996
# ====================================================================================================
#
# ====================================================================================================
# Epoch:    30	 Steps:     310752	 Average Speed:  1667.79	 Epsilon: 0.8467955199999944
# ----------------------------------------------------------------------------------------------------
# EP Loss            mean/std/max/min	     0.000032	    0.000031	    0.000176	 6.36342e-06
# EP Qmax            mean/std/max/min	     0.141009	    0.033676	    0.192721	   0.0978049
# EP Test Reward     mean/std/max/min	     0.250000	    0.433013	    1.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:    40	 Steps:     410592	 Average Speed:  1777.47	 Epsilon: 0.7973747199999925
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	     0.000000	    0.000000	    0.000000	         0.0
# EP Loss            mean/std/max/min	     0.000018	    0.000017	    0.000111	 4.43743e-06
# EP Qmax            mean/std/max/min	     0.138365	    0.030091	    0.188322	     0.10757
# EP Test Reward     mean/std/max/min	     0.250000	    0.433013	    1.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:    50	 Steps:     510432	 Average Speed:  1810.76	 Epsilon: 0.7479539199999907
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	     0.000000	    0.000000	    0.000000	         0.0
# EP Loss            mean/std/max/min	     0.000012	    0.000010	    0.000098	 3.57001e-06
# EP Qmax            mean/std/max/min	     0.233346	    0.069371	    0.317465	     0.15535
# EP Test Reward     mean/std/max/min	     0.187500	    0.390312	    1.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:    60	 Steps:     610272	 Average Speed:  1865.81	 Epsilon: 0.6985331199999889
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	     0.000000	    0.000000	    0.000000	         0.0
# EP Loss            mean/std/max/min	     0.000012	    0.000044	    0.000976	 2.67973e-06
# EP Qmax            mean/std/max/min	     0.218453	    0.078160	    0.300406	    0.109952
# EP Test Reward     mean/std/max/min	     0.187500	    0.390312	    1.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:    70	 Steps:     710112	 Average Speed:  1844.57	 Epsilon: 0.6491123199999871
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	     0.000000	    0.000000	    0.000000	         0.0
# EP Loss            mean/std/max/min	     0.000015	    0.000081	    0.000992	 2.14644e-06
# EP Qmax            mean/std/max/min	     0.107879	    0.014880	    0.141660	   0.0890494
# EP Test Reward     mean/std/max/min	     0.125000	    0.330719	    1.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:    80	 Steps:     811200	 Average Speed:  1869.35	 Epsilon: 0.5990737599999852
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	     0.000000	    0.000000	    0.000000	         0.0
# EP Loss            mean/std/max/min	     0.000012	    0.000062	    0.001002	 1.49497e-06
# EP Qmax            mean/std/max/min	     0.115287	    0.025774	    0.181370	   0.0884249
# EP Test Reward     mean/std/max/min	     0.125000	    0.330719	    1.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:    90	 Steps:     911040	 Average Speed:  1882.62	 Epsilon: 0.5496529599999834
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	     0.000000	    0.000000	    0.000000	         0.0
# EP Loss            mean/std/max/min	     0.000162	    0.001566	    0.032167	 1.48647e-06
# EP Qmax            mean/std/max/min	     0.127966	    0.033346	    0.236251	   0.0834639
# EP Test Reward     mean/std/max/min	     0.093750	    0.291481	    1.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   100	 Steps:    1010880	 Average Speed:  1873.41	 Epsilon: 0.5002321599999816
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	     0.000000	    0.000000	    0.000000	         0.0
# EP Loss            mean/std/max/min	     0.000023	    0.000122	    0.000993	 1.20536e-06
# EP Qmax            mean/std/max/min	     0.151373	    0.047121	    0.255705	    0.102394
# EP Test Reward     mean/std/max/min	     0.093750	    0.291481	    1.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   110	 Steps:    1110720	 Average Speed:  1867.48	 Epsilon: 0.4508113599999798
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	     0.000000	    0.000000	    0.000000	         0.0
# EP Loss            mean/std/max/min	     0.000035	    0.000165	    0.001977	 9.40876e-07
# EP Qmax            mean/std/max/min	     0.094135	    0.015142	    0.126175	   0.0751496
# EP Test Reward     mean/std/max/min	     0.075000	    0.263391	    1.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   120	 Steps:    1210560	 Average Speed:  1861.86	 Epsilon: 0.40139055999997797
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	     0.024306	    0.357605	    6.000000	         0.0
# EP Loss            mean/std/max/min	     0.000109	    0.000320	    0.001991	 9.57497e-07
# EP Qmax            mean/std/max/min	     0.104803	    0.017711	    0.129998	   0.0722341
# EP Test Reward     mean/std/max/min	     0.075000	    0.263391	    1.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   130	 Steps:    1310400	 Average Speed:  1863.84	 Epsilon: 0.35196975999997615
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	     0.031250	    0.339854	    6.000000	         0.0
# EP Loss            mean/std/max/min	     0.000312	    0.000541	    0.005008	 1.32907e-06
# EP Qmax            mean/std/max/min	     0.123356	    0.049683	    0.228245	    0.078034
# EP Test Reward     mean/std/max/min	     0.075000	    0.263391	    1.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   140	 Steps:    1410240	 Average Speed:  1847.97	 Epsilon: 0.30254895999997433
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	     0.029891	    0.332445	    6.000000	         0.0
# EP Loss            mean/std/max/min	     0.000559	    0.000706	    0.003997	 4.69049e-06
# EP Qmax            mean/std/max/min	     0.132497	    0.056916	    0.233898	   0.0685838
# EP Test Reward     mean/std/max/min	     0.083333	    0.276385	    1.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   150	 Steps:    1510080	 Average Speed:  1853.71	 Epsilon: 0.2531281599999725
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	     0.028646	    0.325500	    6.000000	         0.0
# EP Loss            mean/std/max/min	     0.000899	    0.000821	    0.005468	 3.53536e-05
# EP Qmax            mean/std/max/min	     0.176452	    0.147141	    0.899962	   0.0206369
# EP Test Reward     mean/std/max/min	     0.083333	    0.276385	    1.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   160	 Steps:    1611168	 Average Speed:  1861.06	 Epsilon: 0.20308959999997278
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	     0.087500	    0.519465	    6.000000	         0.0
# EP Loss            mean/std/max/min	     0.001476	    0.000977	    0.005657	 9.96183e-05
# EP Qmax            mean/std/max/min	     0.263952	    0.273900	    1.281156	   -0.155395
# EP Test Reward     mean/std/max/min	     1.044643	    3.571685	   27.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   170	 Steps:    1711008	 Average Speed:  1873.68	 Epsilon: 0.15366879999997318
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	     0.439655	    1.603008	   15.000000	         0.0
# EP Loss            mean/std/max/min	     0.003980	    0.001621	    0.013034	 0.000703019
# EP Qmax            mean/std/max/min	     0.253597	    0.300997	    1.476725	   -0.231144
# EP Test Reward     mean/std/max/min	     1.044643	    3.571685	   27.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   180	 Steps:    1810848	 Average Speed:  1871.49	 Epsilon: 0.10424799999997358
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	     0.583333	    2.147996	   28.000000	         0.0
# EP Loss            mean/std/max/min	     0.006939	    0.002415	    0.015897	  0.00188473
# EP Qmax            mean/std/max/min	     0.117328	    0.198919	    0.684167	   -0.381683
# EP Test Reward     mean/std/max/min	     1.044643	    3.571685	   27.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   190	 Steps:    1910688	 Average Speed:  1865.82	 Epsilon: 0.054827199999973895
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	     0.842742	    2.863048	   30.000000	         0.0
# EP Loss            mean/std/max/min	     0.010412	    0.003404	    0.021944	   0.0035927
# EP Qmax            mean/std/max/min	     0.332087	    0.589162	    1.918504	   -0.709949
# EP Test Reward     mean/std/max/min	     3.000000	    7.096434	   42.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   200	 Steps:    2010528	 Average Speed:  1855.49	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	     2.094697	    6.423982	   43.000000	         0.0
# EP Loss            mean/std/max/min	     0.015783	    0.004411	    0.034113	  0.00609975
# EP Qmax            mean/std/max/min	     0.533497	    0.729997	    2.748036	   -0.627468
# EP Test Reward     mean/std/max/min	     7.458333	   16.694508	   89.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   210	 Steps:    2110368	 Average Speed:  1854.06	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	     5.176573	   13.390658	   89.000000	         0.0
# EP Loss            mean/std/max/min	     0.020637	    0.004315	    0.044141	   0.0092227
# EP Qmax            mean/std/max/min	     1.791463	    1.101658	    3.848406	   -0.247971
# EP Test Reward     mean/std/max/min	     7.458333	   16.694508	   89.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   220	 Steps:    2210208	 Average Speed:  1845.04	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	     8.835526	   20.945086	  143.000000	         0.0
# EP Loss            mean/std/max/min	     0.029440	    0.005894	    0.057779	   0.0161689
# EP Qmax            mean/std/max/min	     1.073612	    1.199764	    3.738530	   -0.060005
# EP Test Reward     mean/std/max/min	     7.458333	   16.694508	   89.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   230	 Steps:    2310048	 Average Speed:  1837.97	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	    15.312989	   35.570851	  187.000000	         0.0
# EP Loss            mean/std/max/min	     0.035368	    0.006768	    0.072448	   0.0185863
# EP Qmax            mean/std/max/min	     1.977271	    0.925240	    4.953940	    0.632927
# EP Test Reward     mean/std/max/min	    20.937500	   43.913080	  170.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   240	 Steps:    2411136	 Average Speed:  1834.66	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	    18.459542	   40.523533	  187.000000	         0.0
# EP Loss            mean/std/max/min	     0.042396	    0.007801	    0.073944	    0.024546
# EP Qmax            mean/std/max/min	     1.498846	    1.001538	    3.002327	   -0.564136
# EP Test Reward     mean/std/max/min	    30.270588	   56.708105	  194.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   250	 Steps:    2510976	 Average Speed:  1835.25	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	    24.439883	   49.617866	  197.000000	         0.0
# EP Loss            mean/std/max/min	     0.047875	    0.008787	    0.082713	   0.0256561
# EP Qmax            mean/std/max/min	     3.252348	    1.690659	    5.674711	   -0.418598
# EP Test Reward     mean/std/max/min	    30.270588	   56.708105	  194.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   260	 Steps:    2610816	 Average Speed:  1824.94	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	    29.142248	   55.803121	  198.000000	         0.0
# EP Loss            mean/std/max/min	     0.051657	    0.009068	    0.086834	   0.0321318
# EP Qmax            mean/std/max/min	     3.358073	    1.195284	    5.585310	 -0.00539504
# EP Test Reward     mean/std/max/min	    30.270588	   56.708105	  194.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   270	 Steps:    2710656	 Average Speed:  1819.14	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	    32.962500	   61.053506	  422.000000	         0.0
# EP Loss            mean/std/max/min	     0.060263	    0.010558	    0.099953	   0.0335674
# EP Qmax            mean/std/max/min	     3.255965	    1.939181	    6.544888	   -0.179756
# EP Test Reward     mean/std/max/min	    43.395480	   86.492948	  448.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   280	 Steps:    2810496	 Average Speed:  1818.60	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	    33.843923	   62.022801	  422.000000	         0.0
# EP Loss            mean/std/max/min	     0.066570	    0.011016	    0.128550	   0.0416613
# EP Qmax            mean/std/max/min	     3.666636	    2.245099	    7.076041	  -0.0435161
# EP Test Reward     mean/std/max/min	    58.301075	  108.424374	  448.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   290	 Steps:    2910336	 Average Speed:  1810.81	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	    36.733882	   70.972670	  493.000000	         0.0
# EP Loss            mean/std/max/min	     0.072398	    0.012493	    0.152998	   0.0469115
# EP Qmax            mean/std/max/min	     4.553904	    1.708964	    7.709791	   0.0332378
# EP Test Reward     mean/std/max/min	    58.301075	  108.424374	  448.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   300	 Steps:    3010176	 Average Speed:  1810.17	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	    38.436562	   74.794838	  493.000000	         0.0
# EP Loss            mean/std/max/min	     0.077489	    0.013579	    0.127366	   0.0434467
# EP Qmax            mean/std/max/min	     4.903618	    1.224273	    8.085169	      2.2867
# EP Test Reward     mean/std/max/min	    58.301075	  108.424374	  448.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   310	 Steps:    3110016	 Average Speed:  1808.00	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	    51.723460	   99.149758	  493.000000	         0.0
# EP Loss            mean/std/max/min	     0.076620	    0.014292	    0.144951	   0.0449924
# EP Qmax            mean/std/max/min	     4.445052	    2.392814	    8.565363	  -0.0734559
# EP Test Reward     mean/std/max/min	    68.429319	  125.587891	  715.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   320	 Steps:    3211104	 Average Speed:  1800.57	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	    61.717916	  113.873441	  493.000000	         0.0
# EP Loss            mean/std/max/min	     0.082113	    0.014792	    0.140593	   0.0510059
# EP Qmax            mean/std/max/min	     4.117491	    2.060064	    8.239455	    0.223167
# EP Test Reward     mean/std/max/min	    68.429319	  125.587891	  715.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   330	 Steps:    3310944	 Average Speed:  1799.80	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	    71.698393	  127.396292	  493.000000	         0.0
# EP Loss            mean/std/max/min	     0.082544	    0.016561	    0.137506	   0.0462863
# EP Qmax            mean/std/max/min	     4.810486	    2.177478	   10.127398	     0.51867
# EP Test Reward     mean/std/max/min	    86.788945	  153.413573	  715.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   340	 Steps:    3410784	 Average Speed:  1798.52	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	    72.203453	  127.706514	  493.000000	         0.0
# EP Loss            mean/std/max/min	     0.092650	    0.018362	    0.169571	   0.0486138
# EP Qmax            mean/std/max/min	     6.532930	    1.960959	   11.220306	    0.986879
# EP Test Reward     mean/std/max/min	    86.788945	  153.413573	  715.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   350	 Steps:    3510624	 Average Speed:  1798.52	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	    80.000000	  136.834118	  696.000000	         0.0
# EP Loss            mean/std/max/min	     0.095097	    0.019586	    0.171785	   0.0528782
# EP Qmax            mean/std/max/min	     6.889132	    1.362954	    9.895094	     3.36924
# EP Test Reward     mean/std/max/min	   103.845411	  174.336992	  715.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   360	 Steps:    3610464	 Average Speed:  1788.46	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	    84.272619	  141.518948	  696.000000	         0.0
# EP Loss            mean/std/max/min	     0.094361	    0.019725	    0.160350	    0.052011
# EP Qmax            mean/std/max/min	     5.207740	    3.349645	   12.412147	    0.337479
# EP Test Reward     mean/std/max/min	   103.845411	  174.336992	  715.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   370	 Steps:    3710304	 Average Speed:  1786.04	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	    88.772300	  146.314119	  696.000000	         0.0
# EP Loss            mean/std/max/min	     0.105357	    0.022362	    0.192597	   0.0561832
# EP Qmax            mean/std/max/min	     7.430718	    2.868562	   13.174403	    0.971487
# EP Test Reward     mean/std/max/min	   113.203704	  176.886564	  715.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   380	 Steps:    3810144	 Average Speed:  1784.45	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	    90.667056	  148.728105	  696.000000	         0.0
# EP Loss            mean/std/max/min	     0.113860	    0.024653	    0.226018	   0.0563971
# EP Qmax            mean/std/max/min	     5.694692	    2.752244	    9.347071	    0.593799
# EP Test Reward     mean/std/max/min	   113.203704	  176.886564	  715.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   390	 Steps:    3911232	 Average Speed:  1783.36	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	   106.461969	  165.387864	  748.000000	         0.0
# EP Loss            mean/std/max/min	     0.110680	    0.024569	    0.230977	   0.0489566
# EP Qmax            mean/std/max/min	     8.837274	    1.402015	   12.445538	      4.7982
# EP Test Reward     mean/std/max/min	   120.660633	  181.755038	  715.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   400	 Steps:    4011072	 Average Speed:  1780.00	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	   106.461969	  165.387864	  748.000000	         0.0
# EP Loss            mean/std/max/min	     0.115202	    0.026018	    0.238261	   0.0603198
# EP Qmax            mean/std/max/min	     4.743951	    4.100666	   14.572338	    0.284894
# EP Test Reward     mean/std/max/min	   120.660633	  181.755038	  715.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   410	 Steps:    4110912	 Average Speed:  1771.79	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	   109.133333	  168.362004	  748.000000	         0.0
# EP Loss            mean/std/max/min	     0.113904	    0.026492	    0.227593	   0.0615262
# EP Qmax            mean/std/max/min	     9.399043	    2.730900	   15.190168	      1.2082
# EP Test Reward     mean/std/max/min	   134.873362	  194.792279	  774.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   420	 Steps:    4210752	 Average Speed:  1766.15	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	   117.447340	  175.350202	  748.000000	         0.0
# EP Loss            mean/std/max/min	     0.117359	    0.027272	    0.219019	   0.0630921
# EP Qmax            mean/std/max/min	     8.834854	    1.460842	   11.556897	     2.72202
# EP Test Reward     mean/std/max/min	   134.873362	  194.792279	  774.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   430	 Steps:    4310592	 Average Speed:  1755.45	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	   123.778015	  180.956907	  748.000000	         0.0
# EP Loss            mean/std/max/min	     0.116264	    0.026743	    0.224533	   0.0572571
# EP Qmax            mean/std/max/min	     8.115440	    4.265907	   14.781921	    -1.45716
# EP Test Reward     mean/std/max/min	   147.915612	  206.677273	  774.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   440	 Steps:    4410432	 Average Speed:  1749.64	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	   127.429778	  183.613144	  748.000000	         0.0
# EP Loss            mean/std/max/min	     0.113437	    0.027380	    0.237329	   0.0548553
# EP Qmax            mean/std/max/min	     7.100098	    4.456467	   15.863997	   -0.890713
# EP Test Reward     mean/std/max/min	   147.915612	  206.677273	  774.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   450	 Steps:    4510272	 Average Speed:  1746.13	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	   133.758585	  190.331186	  789.000000	         0.0
# EP Loss            mean/std/max/min	     0.111478	    0.025577	    0.208224	   0.0535029
# EP Qmax            mean/std/max/min	     8.312621	    4.685151	   16.400431	    0.536919
# EP Test Reward     mean/std/max/min	   154.842975	  210.390114	  774.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   460	 Steps:    4610112	 Average Speed:  1740.45	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	   135.663561	  191.787877	  789.000000	         0.0
# EP Loss            mean/std/max/min	     0.119700	    0.028160	    0.239317	   0.0616184
# EP Qmax            mean/std/max/min	     9.869573	    3.740145	   17.371317	     3.86867
# EP Test Reward     mean/std/max/min	   154.842975	  210.390114	  774.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   470	 Steps:    4711200	 Average Speed:  1742.22	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	   140.253579	  195.376180	  789.000000	         0.0
# EP Loss            mean/std/max/min	     0.113425	    0.027238	    0.235889	    0.060792
# EP Qmax            mean/std/max/min	     8.351410	    4.440546	   14.612254	   0.0886016
# EP Test Reward     mean/std/max/min	   170.063492	  220.479321	  774.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   480	 Steps:    4811040	 Average Speed:  1742.46	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	   148.180000	  200.081512	  789.000000	         0.0
# EP Loss            mean/std/max/min	     0.114161	    0.029289	    0.236394	   0.0578416
# EP Qmax            mean/std/max/min	    10.586589	    2.385477	   16.771416	     1.28964
# EP Test Reward     mean/std/max/min	   170.063492	  220.479321	  774.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   490	 Steps:    4910880	 Average Speed:  1740.22	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	   151.016000	  202.207230	  798.000000	         0.0
# EP Loss            mean/std/max/min	     0.112405	    0.028673	    0.225850	   0.0540316
# EP Qmax            mean/std/max/min	    10.759092	    2.252327	   16.434246	     5.60052
# EP Test Reward     mean/std/max/min	   170.063492	  220.479321	  774.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   500	 Steps:    5010720	 Average Speed:  1738.00	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	   159.855000	  208.496902	 1023.000000	         0.0
# EP Loss            mean/std/max/min	     0.115565	    0.028491	    0.238133	   0.0597074
# EP Qmax            mean/std/max/min	     6.806155	    4.283555	   13.861639	   -0.180065
# EP Test Reward     mean/std/max/min	   174.250980	  222.817149	  774.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   510	 Steps:    5110560	 Average Speed:  1732.95	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	   166.131000	  210.950449	 1023.000000	         0.0
# EP Loss            mean/std/max/min	     0.114387	    0.029801	    0.247009	   0.0555345
# EP Qmax            mean/std/max/min	     6.187752	    5.426535	   15.814807	    0.524084
# EP Test Reward     mean/std/max/min	   174.250980	  222.817149	  774.000000	         0.0
# ====================================================================================================
#
# ====================================================================================================
# Epoch:   520	 Steps:    5210400	 Average Speed:  1733.04	 Epsilon: 0.01
# ----------------------------------------------------------------------------------------------------
# EP Training Reward mean/std/max/min	   172.612000	  216.016503	 1023.000000	         0.0
# EP Loss            mean/std/max/min	     0.121760	    0.030556	    0.232241	   0.0611165
# EP Qmax            mean/std/max/min	     9.664162	    3.742751	   14.859922	    0.370946
# EP Test Reward     mean/std/max/min	   186.359848	  229.353495	  774.000000	         0.0
# ====================================================================================================

# %%
# plt.plot(TRs)
# device = torch.device('cuda:0')
# replay = deque(maxlen=10000)
# datas = [np.random.randn(1000, 32)] * 5
# for entry in zip(*datas):
#     replay.append(entry)
#     
# dataset = ReplayDataset(replay)
# dataloader = DataLoaderX(dataset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)
# print(next(iter(dataloader)))
# datafetcher = DataPrefetcher(dataloader, device)
# datafetcher.preload()

# %%
# LLs = []
# RRs = []
# for epoch in range(10):
#     model, model_target, Ls = train(model, model_target)
#     # Rs = test(model)
#     LLs += Ls
#     # RRs += Rs

game
# Out:
# 'Enduro'

# %%
# import torch
# data = torch.load('././ckpt/Breakout_e500')

# %%
# import matplotlib.pyplot as plt
# 
# for k, v in data.items():
#     if k != 'model':
#         if isinstance(v, list):
#             if len(v) > 0:
#                 plt.plot(v, label=k)
# 
# plt.legend()
# data.keys()

# %%
# plt.figure(figsize=(12, 9), dpi=300)
# plt.plot(data['Rs'])
